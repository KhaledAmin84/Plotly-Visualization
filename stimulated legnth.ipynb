# %%
# !pip install yellowbrick
# Out:
# ...
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from yellowbrick.features import JointPlotVisualizer

# %%
data = pd.read_csv(r"C:\Users\Dell\Desktop\Data_AI_Academy\well_data_raw.csv")

data
# Out:
#     well_id  avg_proppant_placed_per_stage  fluid_per_stimulated_length  \
# 0      w198                     202.197691                    14.756018
# 1      w434                     186.223800                     7.433044
# 2      w116                     158.380152                    22.099161
# 3      w404                     294.000000                    19.358398
# 4      w199                     250.231580                    12.989235
# ..      ...                            ...                          ...
# 539    w213                      97.891216                    24.996247
# 540    w234                     268.275000                    23.512870
# 541    w484                     192.491250                    20.527636
# 542    w231                      72.244568                    24.261048
# 543    w600                     283.500000                    19.963912
#
#      proppant_fluid_ratio  proppant_per_stage  proppant_per_stimulated_length  \
# ...

# %%
jpv = JointPlotVisualizer(columns=["month_on_production" , "stimulated_length"])
jpv.fit_transform(data)

# Stilulated legnth mean the legnth of the fraction inside the formation
# Out:
#     well_id  avg_proppant_placed_per_stage  fluid_per_stimulated_length  \
# 0      w198                     202.197691                    14.756018
# 1      w434                     186.223800                     7.433044
# 2      w116                     158.380152                    22.099161
# 3      w404                     294.000000                    19.358398
# 4      w199                     250.231580                    12.989235
# ..      ...                            ...                          ...
# 539    w213                      97.891216                    24.996247
# 540    w234                     268.275000                    23.512870
# 541    w484                     192.491250                    20.527636
# 542    w231                      72.244568                    24.261048
# 543    w600                     283.500000                    19.963912
#
#      proppant_fluid_ratio  proppant_per_stage  proppant_per_stimulated_length  \
# ...

# %%
import seaborn as sns

# %%
# another polot by seaborn

sns.jointplot(x="month_on_production" , y="stimulated_length", data=data, kind="reg")

# %%
sns.jointplot(x="month_on_production" , y="stimulated_length", data=data, kind="hex")

# %%
sns.pairplot(data=data , vars=["month_on_production" ,"stimulated_length" , "cum_12_gas_prod"] , kind="reg" , hue="fluid", height=3)
